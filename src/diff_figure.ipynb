# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus']=False

# %%
pd.set_option('display.max_rows', 100)

# %%
path = r'C:\Users\Una\Desktop\Una\Courses\108-1\R\project\data\all.xlsx'
df_all = pd.read_excel(path)

# %%
path1 = r'C:\Users\Una\Desktop\Una\Courses\108-1\R\project\data\minor_in_apply_diff_2.xlsx'
df_trans = pd.read_excel(path1)

# %%
df_all.head()
# Out:
#     id    年度    代碼           學系 學院  轉系轉出申請  轉系轉出核准  轉系轉入申請志願1  轉系轉入申請志願2  \
# 0  1.0  99.0  1010        中國文學系  文     8.0     4.0        4.0        0.0
# 1  2.0  99.0  1011      中文國際學士班  文     NaN     NaN        NaN        NaN
# 2  3.0  99.0  1020       外國語文學系  文     4.0     2.0       14.0        5.0
# 3  4.0  99.0  102A  外國語文學系（文學組）  文     0.0     0.0        0.0        0.0
# 4  5.0  99.0  102B  外國語文學系（語言組）  文     0.0     0.0        0.0        0.0
#
#    轉系轉入申請  ... 輔系轉出核准  輔系轉入申請  輔系轉入核准                                輔系轉入招收名額  \
# 0       4  ...   16.0    76.0    16.0  同一年級各系之學生總共以不超過20名為原則。(國際生每年以不超過2名為原則)
# 1       0  ...    NaN     NaN     NaN                                     NaN
# 2      19  ...   24.0     0.0     0.0                                      15
# 3       0  ...    0.0    77.0    10.0                                      --
# 4       0  ...    0.0   153.0     5.0                                      --
#
#    上學期就讀人數  下學期就讀人數  考試分發  繁星計畫  個人申請  新生數
# ...

# %%
df_trans
# Out:
#        dp  diff
# 0    1010  44.0
# 1    1011   NaN
# 2    1020   0.0
# 3    102A  29.0
# 4    102B  11.0
# ..    ...   ...
# 568  A011   0.0
# 569  A012   0.0
# 570  A013   0.0
# 571  B010  -2.0
# 572  B020 -13.0
#
# [573 rows x 2 columns]

# %%
for i in set(df_all.代碼):
    df =df_trans[df_trans.dp==i]
    if (len(df)==9):
        df['dp'] = range(100,109)
    
        plt.plot(df['dp'],df['diff'])
        plt.plot(range(100,109),[0,0,0,0,0,0,0,0,0],color='r')
        plt.xticks(rotation=90)
        plt.title(str(i)+'申請輔系人數變化')
        plt.xlabel('年度')
        plt.ylabel('人數')
        plt.show()
    else:
        print()
# Out:
# C:\Users\Una\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
